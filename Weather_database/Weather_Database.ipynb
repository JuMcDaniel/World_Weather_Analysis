# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_current = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        

        # Append the city information into city_data list.
        
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_current,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
        

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | neyshabur
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | longyearbyen
# Processing Record 6 of Set 1 | talcahuano
# Processing Record 7 of Set 1 | sarai alamgir
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | castro
# Processing Record 10 of Set 1 | ostrovnoy
# Processing Record 11 of Set 1 | victoria
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | saint-philippe
# Processing Record 14 of Set 1 | pontian kecil
# Processing Record 15 of Set 1 | namibe
# Processing Record 16 of Set 1 | bamako
# Processing Record 17 of Set 1 | manuk mangkaw
# Processing Record 18 of Set 1 | kinsale
# Processing Record 19 of Set 1 | hualmay
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | kyabe
# Processing Record 22 of Set 1 | lipin bor
# Processing Record 23 of Set 1 | castanos
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | chokurdakh
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | provideniya
# Processing Record 29 of Set 1 | shubarkuduk
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | esperance
# Processing Record 34 of Set 1 | mahebourg
# Processing Record 35 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 1 | portland
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | yining
# Processing Record 42 of Set 1 | vestmanna
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | lae
# Processing Record 45 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 1 | togul
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | kavieng
# Processing Record 50 of Set 1 | pevek
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | kota kinabalu
# Processing Record 4 of Set 2 | george
# Processing Record 5 of Set 2 | bonavista
# Processing Record 6 of Set 2 | kruisfontein
# Processing Record 7 of Set 2 | severo-kurilsk
# Processing Record 8 of Set 2 | tasiilaq
# Processing Record 9 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 2 | port hardy
# Processing Record 11 of Set 2 | tecoanapa
# Processing Record 12 of Set 2 | hershey
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | okha
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 2 | rawlins
# Processing Record 19 of Set 2 | chadiza
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | gizo
# Processing Record 22 of Set 2 | naze
# Processing Record 23 of Set 2 | bengkulu
# Processing Record 24 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 2 | pisco
# Processing Record 26 of Set 2 | mayumba
# Processing Record 27 of Set 2 | saint-leu
# Processing Record 28 of Set 2 | kunashak
# Processing Record 29 of Set 2 | lubawa
# Processing Record 30 of Set 2 | verkhoyansk
# Processing Record 31 of Set 2 | neufahrn
# Processing Record 32 of Set 2 | hobart
# Processing Record 33 of Set 2 | zhezkazgan
# Processing Record 34 of Set 2 | monte azul paulista
# Processing Record 35 of Set 2 | palencia
# Processing Record 36 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 2 | skiathos
# Processing Record 38 of Set 2 | yanam
# Processing Record 39 of Set 2 | golden
# Processing Record 40 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 2 | coquimbo
# Processing Record 42 of Set 2 | carnarvon
# Processing Record 43 of Set 2 | burica
# City not found. Skipping...
# Processing Record 44 of Set 2 | camaqua
# Processing Record 45 of Set 2 | maltahohe
# Processing Record 46 of Set 2 | jizan
# Processing Record 47 of Set 2 | tapiramuta
# Processing Record 48 of Set 2 | aden
# Processing Record 49 of Set 2 | bannu
# Processing Record 50 of Set 2 | yuksekova
# Processing Record 1 of Set 3 | schwanewede
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | ilulissat
# Processing Record 4 of Set 3 | sembakung
# Processing Record 5 of Set 3 | port-de-bouc
# Processing Record 6 of Set 3 | xuddur
# Processing Record 7 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 3 | hofn
# Processing Record 9 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 3 | iralaya
# Processing Record 11 of Set 3 | isangel
# Processing Record 12 of Set 3 | broken hill
# Processing Record 13 of Set 3 | cape town
# Processing Record 14 of Set 3 | tanggu
# Processing Record 15 of Set 3 | bolshaya sosnova
# Processing Record 16 of Set 3 | port lincoln
# Processing Record 17 of Set 3 | port alfred
# Processing Record 18 of Set 3 | axim
# Processing Record 19 of Set 3 | upernavik
# Processing Record 20 of Set 3 | dingle
# Processing Record 21 of Set 3 | uchiza
# Processing Record 22 of Set 3 | muros
# Processing Record 23 of Set 3 | sorong
# Processing Record 24 of Set 3 | umm kaddadah
# Processing Record 25 of Set 3 | warri
# Processing Record 26 of Set 3 | tiksi
# Processing Record 27 of Set 3 | acapulco
# Processing Record 28 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 29 of Set 3 | myitkyina
# Processing Record 30 of Set 3 | pringsewu
# Processing Record 31 of Set 3 | bredasdorp
# Processing Record 32 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 3 | rascani
# City not found. Skipping...
# Processing Record 34 of Set 3 | faanui
# Processing Record 35 of Set 3 | katsuura
# Processing Record 36 of Set 3 | pontivy
# Processing Record 37 of Set 3 | kapaa
# Processing Record 38 of Set 3 | sagua la grande
# Processing Record 39 of Set 3 | yulara
# Processing Record 40 of Set 3 | issoudun
# Processing Record 41 of Set 3 | shimoda
# Processing Record 42 of Set 3 | bull savanna
# Processing Record 43 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 3 | san marcos
# Processing Record 45 of Set 3 | iturama
# Processing Record 46 of Set 3 | cerro largo
# Processing Record 47 of Set 3 | torbay
# Processing Record 48 of Set 3 | natal
# Processing Record 49 of Set 3 | uwayl
# City not found. Skipping...
# Processing Record 50 of Set 3 | bandarbeyla
# Processing Record 1 of Set 4 | tashtyp
# Processing Record 2 of Set 4 | fortuna
# Processing Record 3 of Set 4 | emerald
# Processing Record 4 of Set 4 | sao filipe
# Processing Record 5 of Set 4 | la ronge
# Processing Record 6 of Set 4 | lisieux
# Processing Record 7 of Set 4 | wlodawa
# Processing Record 8 of Set 4 | sitka
# Processing Record 9 of Set 4 | ratnagiri
# Processing Record 10 of Set 4 | waipawa
# Processing Record 11 of Set 4 | karasuk
# Processing Record 12 of Set 4 | yarada
# Processing Record 13 of Set 4 | beira
# Processing Record 14 of Set 4 | mazatlan
# Processing Record 15 of Set 4 | touros
# Processing Record 16 of Set 4 | nouadhibou
# Processing Record 17 of Set 4 | lavrentiya
# Processing Record 18 of Set 4 | hambantota
# Processing Record 19 of Set 4 | barrow
# Processing Record 20 of Set 4 | dedza
# Processing Record 21 of Set 4 | oranjestad
# Processing Record 22 of Set 4 | plonsk
# Processing Record 23 of Set 4 | mount isa
# Processing Record 24 of Set 4 | damaturu
# Processing Record 25 of Set 4 | tuktoyaktuk
# Processing Record 26 of Set 4 | ouesso
# Processing Record 27 of Set 4 | portree
# Processing Record 28 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 4 | chapais
# Processing Record 30 of Set 4 | nha trang
# Processing Record 31 of Set 4 | hithadhoo
# Processing Record 32 of Set 4 | zeya
# Processing Record 33 of Set 4 | fukue
# Processing Record 34 of Set 4 | thunder bay
# Processing Record 35 of Set 4 | moba
# Processing Record 36 of Set 4 | lewistown
# Processing Record 37 of Set 4 | east london
# Processing Record 38 of Set 4 | muli
# Processing Record 39 of Set 4 | manggar
# Processing Record 40 of Set 4 | vienenburg
# Processing Record 41 of Set 4 | broome
# Processing Record 42 of Set 4 | nikolskoye
# Processing Record 43 of Set 4 | finschhafen
# Processing Record 44 of Set 4 | ostroda
# Processing Record 45 of Set 4 | sao caetano de odivelas
# Processing Record 46 of Set 4 | manakara
# Processing Record 47 of Set 4 | sao joao da barra
# Processing Record 48 of Set 4 | ribeira grande
# Processing Record 49 of Set 4 | bay city
# Processing Record 50 of Set 4 | salalah
# Processing Record 1 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 5 | krasnoarmeysk
# Processing Record 3 of Set 5 | hasaki
# Processing Record 4 of Set 5 | dalaba
# Processing Record 5 of Set 5 | ekibastuz
# Processing Record 6 of Set 5 | baruun-urt
# Processing Record 7 of Set 5 | sun city west
# Processing Record 8 of Set 5 | gilbues
# Processing Record 9 of Set 5 | butaritari
# Processing Record 10 of Set 5 | shadrinsk
# Processing Record 11 of Set 5 | qaqortoq
# Processing Record 12 of Set 5 | soledade
# Processing Record 13 of Set 5 | avarua
# Processing Record 14 of Set 5 | korcula
# Processing Record 15 of Set 5 | yellowknife
# Processing Record 16 of Set 5 | jardim
# Processing Record 17 of Set 5 | sergeyevka
# Processing Record 18 of Set 5 | dorobantu
# Processing Record 19 of Set 5 | tiarei
# Processing Record 20 of Set 5 | semey
# Processing Record 21 of Set 5 | bethel
# Processing Record 22 of Set 5 | wanning
# Processing Record 23 of Set 5 | along
# Processing Record 24 of Set 5 | nome
# Processing Record 25 of Set 5 | georgetown
# Processing Record 26 of Set 5 | panjab
# Processing Record 27 of Set 5 | lumby
# Processing Record 28 of Set 5 | saint anthony
# Processing Record 29 of Set 5 | innellan
# Processing Record 30 of Set 5 | lorengau
# Processing Record 31 of Set 5 | klaksvik
# Processing Record 32 of Set 5 | puerto leguizamo
# Processing Record 33 of Set 5 | linkoping
# Processing Record 34 of Set 5 | markivka
# Processing Record 35 of Set 5 | kieta
# Processing Record 36 of Set 5 | sangin
# Processing Record 37 of Set 5 | roald
# Processing Record 38 of Set 5 | shu
# Processing Record 39 of Set 5 | le port
# Processing Record 40 of Set 5 | bundaberg
# Processing Record 41 of Set 5 | badiraguato
# Processing Record 42 of Set 5 | banda aceh
# Processing Record 43 of Set 5 | nhulunbuy
# Processing Record 44 of Set 5 | cidreira
# Processing Record 45 of Set 5 | boddam
# Processing Record 46 of Set 5 | college
# Processing Record 47 of Set 5 | san jeronimo
# Processing Record 48 of Set 5 | valparaiso
# Processing Record 49 of Set 5 | kuito
# Processing Record 50 of Set 5 | santa cruz cabralia
# Processing Record 1 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 6 | kochi
# Processing Record 3 of Set 6 | buala
# Processing Record 4 of Set 6 | port keats
# Processing Record 5 of Set 6 | chinsali
# Processing Record 6 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 6 | sasykoli
# Processing Record 8 of Set 6 | polunochnoye
# Processing Record 9 of Set 6 | hami
# Processing Record 10 of Set 6 | neftegorsk
# Processing Record 11 of Set 6 | talnakh
# Processing Record 12 of Set 6 | imphal
# Processing Record 13 of Set 6 | ortigueira
# Processing Record 14 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 6 | san angelo
# Processing Record 16 of Set 6 | santa cruz
# Processing Record 17 of Set 6 | heishan
# Processing Record 18 of Set 6 | pangai
# Processing Record 19 of Set 6 | seymchan
# Processing Record 20 of Set 6 | yar-sale
# Processing Record 21 of Set 6 | mount gambier
# Processing Record 22 of Set 6 | alice springs
# Processing Record 23 of Set 6 | dumas
# Processing Record 24 of Set 6 | maningrida
# Processing Record 25 of Set 6 | dolores
# Processing Record 26 of Set 6 | lompoc
# Processing Record 27 of Set 6 | apozol
# Processing Record 28 of Set 6 | madang
# Processing Record 29 of Set 6 | berdigestyakh
# Processing Record 30 of Set 6 | santa maria
# Processing Record 31 of Set 6 | maxixe
# Processing Record 32 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 33 of Set 6 | bathsheba
# Processing Record 34 of Set 6 | general roca
# Processing Record 35 of Set 6 | tyumentsevo
# Processing Record 36 of Set 6 | andenes
# Processing Record 37 of Set 6 | ayan
# Processing Record 38 of Set 6 | kodino
# Processing Record 39 of Set 6 | mayahi
# Processing Record 40 of Set 6 | byron bay
# Processing Record 41 of Set 6 | beringovskiy
# Processing Record 42 of Set 6 | saint-francois
# Processing Record 43 of Set 6 | yuci
# Processing Record 44 of Set 6 | russell
# Processing Record 45 of Set 6 | nouakchott
# Processing Record 46 of Set 6 | nieves
# Processing Record 47 of Set 6 | luderitz
# Processing Record 48 of Set 6 | arlit
# Processing Record 49 of Set 6 | tuatapere
# Processing Record 50 of Set 6 | inyonga
# Processing Record 1 of Set 7 | sisimiut
# Processing Record 2 of Set 7 | whitehorse
# Processing Record 3 of Set 7 | ponta do sol
# Processing Record 4 of Set 7 | macamic
# Processing Record 5 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 7 | chuy
# Processing Record 7 of Set 7 | svetlaya
# Processing Record 8 of Set 7 | saint george
# Processing Record 9 of Set 7 | vao
# Processing Record 10 of Set 7 | tambopata
# Processing Record 11 of Set 7 | radcliff
# Processing Record 12 of Set 7 | husainabad
# Processing Record 13 of Set 7 | santiago de cao
# Processing Record 14 of Set 7 | san cristobal
# Processing Record 15 of Set 7 | labuhan
# Processing Record 16 of Set 7 | ambulu
# Processing Record 17 of Set 7 | gospic
# Processing Record 18 of Set 7 | pandamatenga
# Processing Record 19 of Set 7 | vanimo
# Processing Record 20 of Set 7 | winslow
# Processing Record 21 of Set 7 | port blair
# Processing Record 22 of Set 7 | olot
# Processing Record 23 of Set 7 | talaya
# Processing Record 24 of Set 7 | plouzane
# Processing Record 25 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 7 | amzya
# Processing Record 27 of Set 7 | mecca
# Processing Record 28 of Set 7 | arman
# Processing Record 29 of Set 7 | ponta delgada
# Processing Record 30 of Set 7 | abnub
# Processing Record 31 of Set 7 | shancheng
# Processing Record 32 of Set 7 | almaznyy
# Processing Record 33 of Set 7 | belawan
# Processing Record 34 of Set 7 | te anau
# Processing Record 35 of Set 7 | mingshui
# Processing Record 36 of Set 7 | rute
# Processing Record 37 of Set 7 | moron
# Processing Record 38 of Set 7 | fairbanks
# Processing Record 39 of Set 7 | daru
# Processing Record 40 of Set 7 | almeirim
# Processing Record 41 of Set 7 | barroualie
# City not found. Skipping...
# Processing Record 42 of Set 7 | coahuayana
# Processing Record 43 of Set 7 | proletariy
# Processing Record 44 of Set 7 | gornopravdinsk
# Processing Record 45 of Set 7 | mackenzie
# Processing Record 46 of Set 7 | narsaq
# Processing Record 47 of Set 7 | barra do garcas
# Processing Record 48 of Set 7 | otane
# Processing Record 49 of Set 7 | bambous virieux
# Processing Record 50 of Set 7 | saldanha
# Processing Record 1 of Set 8 | xichang
# Processing Record 2 of Set 8 | kamarion
# Processing Record 3 of Set 8 | vila franca do campo
# Processing Record 4 of Set 8 | neulengbach
# Processing Record 5 of Set 8 | sibolga
# Processing Record 6 of Set 8 | boa vista
# Processing Record 7 of Set 8 | srednekolymsk
# Processing Record 8 of Set 8 | korla
# Processing Record 9 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 10 of Set 8 | norman wells
# Processing Record 11 of Set 8 | gat
# Processing Record 12 of Set 8 | ewa beach
# Processing Record 13 of Set 8 | oktyabrskiy
# Processing Record 14 of Set 8 | ilula
# Processing Record 15 of Set 8 | tucurui
# Processing Record 16 of Set 8 | ixtapa
# Processing Record 17 of Set 8 | kaitangata
# Processing Record 18 of Set 8 | mindelo
# Processing Record 19 of Set 8 | elko
# Processing Record 20 of Set 8 | rjukan
# Processing Record 21 of Set 8 | khandyga
# Processing Record 22 of Set 8 | dzhebariki-khaya
# Processing Record 23 of Set 8 | ancud
# Processing Record 24 of Set 8 | shihezi
# Processing Record 25 of Set 8 | moa
# Processing Record 26 of Set 8 | khonsa
# Processing Record 27 of Set 8 | punta cardon
# Processing Record 28 of Set 8 | zlobin
# Processing Record 29 of Set 8 | bredy
# Processing Record 30 of Set 8 | kushmurun
# Processing Record 31 of Set 8 | road town
# Processing Record 32 of Set 8 | nara
# Processing Record 33 of Set 8 | westport
# Processing Record 34 of Set 8 | maridi
# Processing Record 35 of Set 8 | bemidji
# Processing Record 36 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 37 of Set 8 | coihaique
# Processing Record 38 of Set 8 | ocean city
# Processing Record 39 of Set 8 | nanortalik
# Processing Record 40 of Set 8 | ucluelet
# Processing Record 41 of Set 8 | boca do acre
# Processing Record 42 of Set 8 | geraldton
# Processing Record 43 of Set 8 | el alto
# Processing Record 44 of Set 8 | wadi maliz
# Processing Record 45 of Set 8 | mackay
# Processing Record 46 of Set 8 | athens
# Processing Record 47 of Set 8 | sembe
# Processing Record 48 of Set 8 | siva
# Processing Record 49 of Set 8 | gravdal
# Processing Record 50 of Set 8 | vostok
# Processing Record 1 of Set 9 | codrington
# Processing Record 2 of Set 9 | abalak
# Processing Record 3 of Set 9 | cabo san lucas
# Processing Record 4 of Set 9 | murray bridge
# Processing Record 5 of Set 9 | vanderhoof
# Processing Record 6 of Set 9 | oistins
# Processing Record 7 of Set 9 | nakasongola
# Processing Record 8 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 9 of Set 9 | jiangyan
# Processing Record 10 of Set 9 | kongolo
# Processing Record 11 of Set 9 | xai-xai
# Processing Record 12 of Set 9 | san quintin
# Processing Record 13 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 14 of Set 9 | san antonio
# Processing Record 15 of Set 9 | chernyshevskiy
# Processing Record 16 of Set 9 | port said
# Processing Record 17 of Set 9 | dharchula
# Processing Record 18 of Set 9 | mayenne
# Processing Record 19 of Set 9 | ngunguru
# Processing Record 20 of Set 9 | khairpur
# Processing Record 21 of Set 9 | nemuro
# Processing Record 22 of Set 9 | bucine
# Processing Record 23 of Set 9 | north bend
# Processing Record 24 of Set 9 | soe
# Processing Record 25 of Set 9 | deputatskiy
# Processing Record 26 of Set 9 | scarborough
# Processing Record 27 of Set 9 | wajid
# Processing Record 28 of Set 9 | kamenka
# Processing Record 29 of Set 9 | george town
# Processing Record 30 of Set 9 | huambo
# Processing Record 31 of Set 9 | camalu
# Processing Record 32 of Set 9 | alvinopolis
# Processing Record 33 of Set 9 | de-kastri
# Processing Record 34 of Set 9 | port elizabeth
# Processing Record 35 of Set 9 | issa
# Processing Record 36 of Set 9 | moctezuma
# Processing Record 37 of Set 9 | anadyr
# Processing Record 38 of Set 9 | kebemer
# City not found. Skipping...
# Processing Record 39 of Set 9 | rabat
# Processing Record 40 of Set 9 | husavik
# Processing Record 41 of Set 9 | morlaix
# Processing Record 42 of Set 9 | airai
# Processing Record 43 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 44 of Set 9 | kagadi
# Processing Record 45 of Set 9 | mmabatho
# Processing Record 46 of Set 9 | danilovka
# Processing Record 47 of Set 9 | chitral
# Processing Record 48 of Set 9 | monrovia
# Processing Record 49 of Set 9 | sampit
# Processing Record 50 of Set 9 | saint-louis
# Processing Record 1 of Set 10 | torrington
# Processing Record 2 of Set 10 | portsoy
# Processing Record 3 of Set 10 | neiafu
# Processing Record 4 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 10 | payson
# Processing Record 6 of Set 10 | nelson bay
# Processing Record 7 of Set 10 | san
# Processing Record 8 of Set 10 | rayachoti
# Processing Record 9 of Set 10 | newport
# Processing Record 10 of Set 10 | aksu
# Processing Record 11 of Set 10 | lake charles
# Processing Record 12 of Set 10 | khasan
# Processing Record 13 of Set 10 | gigmoto
# Processing Record 14 of Set 10 | ban chang
# Processing Record 15 of Set 10 | paragominas
# Processing Record 16 of Set 10 | nioro
# Processing Record 17 of Set 10 | kyzyl-suu
# Processing Record 18 of Set 10 | dakar
# Processing Record 19 of Set 10 | katobu
# Processing Record 20 of Set 10 | san juan
# Processing Record 21 of Set 10 | ambovombe
# Processing Record 22 of Set 10 | rehoboth
# Processing Record 23 of Set 10 | mercedes
# Processing Record 24 of Set 10 | lasa
# Processing Record 25 of Set 10 | laguna
# Processing Record 26 of Set 10 | surt
# Processing Record 27 of Set 10 | ende
# Processing Record 28 of Set 10 | flin flon
# Processing Record 29 of Set 10 | oranjemund
# Processing Record 30 of Set 10 | hokitika
# Processing Record 31 of Set 10 | snina
# Processing Record 32 of Set 10 | cherskiy
# Processing Record 33 of Set 10 | houma
# Processing Record 34 of Set 10 | jalu
# Processing Record 35 of Set 10 | salgueiro
# Processing Record 36 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 37 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 10 | vestmannaeyjar
# Processing Record 39 of Set 10 | arieseni
# Processing Record 40 of Set 10 | nipawin
# Processing Record 41 of Set 10 | iqaluit
# Processing Record 42 of Set 10 | caohai
# Processing Record 43 of Set 10 | hakkari
# Processing Record 44 of Set 10 | ahuimanu
# Processing Record 45 of Set 10 | palmares do sul
# Processing Record 46 of Set 10 | pavlodar
# Processing Record 47 of Set 10 | rakai
# Processing Record 48 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 10 | komsomolskiy
# Processing Record 50 of Set 10 | limpapa
# Processing Record 1 of Set 11 | savelugu
# Processing Record 2 of Set 11 | puerto escondido
# Processing Record 3 of Set 11 | aykhal
# Processing Record 4 of Set 11 | eureka
# Processing Record 5 of Set 11 | haines junction
# Processing Record 6 of Set 11 | cayenne
# Processing Record 7 of Set 11 | huarmey
# Processing Record 8 of Set 11 | hirara
# Processing Record 9 of Set 11 | dalby
# Processing Record 10 of Set 11 | nanakuli
# Processing Record 11 of Set 11 | obluche
# City not found. Skipping...
# Processing Record 12 of Set 11 | chibombo
# Processing Record 13 of Set 11 | orcopampa
# Processing Record 14 of Set 11 | barranca
# Processing Record 15 of Set 11 | pitimbu
# Processing Record 16 of Set 11 | la rioja
# Processing Record 17 of Set 11 | beeskow
# Processing Record 18 of Set 11 | dalmatovo
# Processing Record 19 of Set 11 | kedarnath
# City not found. Skipping...
# Processing Record 20 of Set 11 | fare
# Processing Record 21 of Set 11 | coracao de maria
# Processing Record 22 of Set 11 | constitucion
# Processing Record 23 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 11 | faya
# Processing Record 25 of Set 11 | warrnambool
# Processing Record 26 of Set 11 | souillac
# Processing Record 27 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 28 of Set 11 | yabassi
# Processing Record 29 of Set 11 | pasadena
# Processing Record 30 of Set 11 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 11 | ahipara
# Processing Record 32 of Set 11 | jaen
# Processing Record 33 of Set 11 | marsa matruh
# Processing Record 34 of Set 11 | gao
# Processing Record 35 of Set 11 | vardo
# Processing Record 36 of Set 11 | yumen
# Processing Record 37 of Set 11 | misratah
# Processing Record 38 of Set 11 | shitanjing
# Processing Record 39 of Set 11 | yambio
# Processing Record 40 of Set 11 | chegdomyn
# Processing Record 41 of Set 11 | guelengdeng
# City not found. Skipping...
# Processing Record 42 of Set 11 | camacha
# Processing Record 43 of Set 11 | rawson
# Processing Record 44 of Set 11 | southampton
# Processing Record 45 of Set 11 | batticaloa
# Processing Record 46 of Set 11 | washington
# Processing Record 47 of Set 11 | buraydah
# Processing Record 48 of Set 11 | belaya gora
# Processing Record 49 of Set 11 | kaeo
# Processing Record 50 of Set 11 | mwingi
# Processing Record 1 of Set 12 | bontang
# Processing Record 2 of Set 12 | imeni poliny osipenko
# Processing Record 3 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 4 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 12 | mineros
# Processing Record 6 of Set 12 | jacmel
# Processing Record 7 of Set 12 | jiayuguan
# Processing Record 8 of Set 12 | collie
# Processing Record 9 of Set 12 | beloha
# Processing Record 10 of Set 12 | narrabri
# Processing Record 11 of Set 12 | fort saint james
# Processing Record 12 of Set 12 | ye
# City not found. Skipping...
# Processing Record 13 of Set 12 | nova odesa
# Processing Record 14 of Set 12 | tigil
# Processing Record 15 of Set 12 | blagoyevo
# Processing Record 16 of Set 12 | harper
# Processing Record 17 of Set 12 | zabaykalsk
# Processing Record 18 of Set 12 | kraskino
# Processing Record 19 of Set 12 | dunedin
# Processing Record 20 of Set 12 | brigantine
# Processing Record 21 of Set 12 | basco
# Processing Record 22 of Set 12 | krasnoselkup
# Processing Record 23 of Set 12 | anupgarh
# Processing Record 24 of Set 12 | skjervoy
# Processing Record 25 of Set 12 | nenjiang
# Processing Record 26 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 12 | parauna
# Processing Record 28 of Set 12 | port augusta
# Processing Record 29 of Set 12 | tchibanga
# Processing Record 30 of Set 12 | cukai
# Processing Record 31 of Set 12 | zunyi
# Processing Record 32 of Set 12 | cap malheureux
# Processing Record 33 of Set 12 | charagua
# Processing Record 34 of Set 12 | teguise
# Processing Record 35 of Set 12 | ntungamo
# Processing Record 36 of Set 12 | vila velha
# Processing Record 37 of Set 12 | paamiut
# Processing Record 38 of Set 12 | taylor
# Processing Record 39 of Set 12 | marsaxlokk
# Processing Record 40 of Set 12 | venado tuerto
# Processing Record 41 of Set 12 | eyl
# Processing Record 42 of Set 12 | nador
# Processing Record 43 of Set 12 | zhangye
# Processing Record 44 of Set 12 | luba
# Processing Record 45 of Set 12 | beyneu
# Processing Record 46 of Set 12 | adrar
# Processing Record 47 of Set 12 | outram
# Processing Record 48 of Set 12 | shache
# Processing Record 49 of Set 12 | tabou
# Processing Record 50 of Set 12 | mahibadhoo
# Processing Record 1 of Set 13 | sri aman
# Processing Record 2 of Set 13 | troitskoye
# Processing Record 3 of Set 13 | asosa
# Processing Record 4 of Set 13 | clyde river
# Processing Record 5 of Set 13 | ornskoldsvik
# Processing Record 6 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 7 of Set 13 | allahganj
# Processing Record 8 of Set 13 | manicore
# Processing Record 9 of Set 13 | tank
# Processing Record 10 of Set 13 | bubaque
# Processing Record 11 of Set 13 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 12 of Set 13 | fuerte olimpo
# Processing Record 13 of Set 13 | yerbogachen
# Processing Record 14 of Set 13 | belmonte
# Processing Record 15 of Set 13 | havre-saint-pierre
# Processing Record 16 of Set 13 | pacifica
# Processing Record 17 of Set 13 | nuuk
# Processing Record 18 of Set 13 | solnechnyy
# Processing Record 19 of Set 13 | sant julia de loria
# Processing Record 20 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 21 of Set 13 | ichinoseki
# Processing Record 22 of Set 13 | hovd
# Processing Record 23 of Set 13 | nizhniy baskunchak
# Processing Record 24 of Set 13 | camacari
# Processing Record 25 of Set 13 | pokhara
# Processing Record 26 of Set 13 | olafsvik
# Processing Record 27 of Set 13 | mnogovershinnyy
# Processing Record 28 of Set 13 | qasigiannguit
# Processing Record 29 of Set 13 | ambanja
# Processing Record 30 of Set 13 | baghdad
# Processing Record 31 of Set 13 | sao raimundo das mangabeiras
# Processing Record 32 of Set 13 | kahului
# Processing Record 33 of Set 13 | koulamoutou
# Processing Record 34 of Set 13 | yakeshi
# Processing Record 35 of Set 13 | bilibino
# Processing Record 36 of Set 13 | anito
# Processing Record 37 of Set 13 | los llanos de aridane
# Processing Record 38 of Set 13 | bobo dioulasso
# Processing Record 39 of Set 13 | lagos
# Processing Record 40 of Set 13 | bowen
# Processing Record 41 of Set 13 | omboue
# Processing Record 42 of Set 13 | lloydminster
# Processing Record 43 of Set 13 | palmer
# Processing Record 44 of Set 13 | sand springs
# Processing Record 45 of Set 13 | rocha
# Processing Record 46 of Set 13 | orlik
# Processing Record 47 of Set 13 | ilinskiy
# Processing Record 48 of Set 13 | kayes
# Processing Record 49 of Set 13 | kudahuvadhoo
# Processing Record 50 of Set 13 | guerrero negro
# Processing Record 1 of Set 14 | lagoa
# Processing Record 2 of Set 14 | bairiki
# Processing Record 3 of Set 14 | monte carmelo
# Processing Record 4 of Set 14 | varzea grande
# Processing Record 5 of Set 14 | sloboda
# Processing Record 6 of Set 14 | ojinaga
# Processing Record 7 of Set 14 | upata
# Processing Record 8 of Set 14 | vryburg
# Processing Record 9 of Set 14 | saint charles
# Processing Record 10 of Set 14 | alofi
# Processing Record 11 of Set 14 | suntar
# Processing Record 12 of Set 14 | champasak
# Processing Record 13 of Set 14 | ust-maya
# Processing Record 14 of Set 14 | aswan
# Processing Record 15 of Set 14 | curup
# Processing Record 16 of Set 14 | sulangan
# Processing Record 17 of Set 14 | dioknisi
# Processing Record 18 of Set 14 | inuvik
# Processing Record 19 of Set 14 | cortez
# Processing Record 20 of Set 14 | dolinsk
# Processing Record 21 of Set 14 | prabumulih
# Processing Record 22 of Set 14 | marau
# Processing Record 23 of Set 14 | rabo de peixe
# Processing Record 24 of Set 14 | chanute
# Processing Record 25 of Set 14 | havelock
# Processing Record 26 of Set 14 | yatou
# Processing Record 27 of Set 14 | durango
# Processing Record 28 of Set 14 | kosh-agach
# Processing Record 29 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 30 of Set 14 | port macquarie
# Processing Record 31 of Set 14 | zelenogradsk
# Processing Record 32 of Set 14 | stargard szczecinski
# Processing Record 33 of Set 14 | tamandare
# Processing Record 34 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 35 of Set 14 | cockburn town
# Processing Record 36 of Set 14 | boende
# Processing Record 37 of Set 14 | kununurra
# Processing Record 38 of Set 14 | tomatlan
# Processing Record 39 of Set 14 | hamilton
# Processing Record 40 of Set 14 | sobolevo
# Processing Record 41 of Set 14 | asyut
# Processing Record 42 of Set 14 | san fernando
# Processing Record 43 of Set 14 | meadow lake
# Processing Record 44 of Set 14 | sur
# Processing Record 45 of Set 14 | atyrau
# Processing Record 46 of Set 14 | benguela
# Processing Record 47 of Set 14 | neftcala
# Processing Record 48 of Set 14 | kavaratti
# Processing Record 49 of Set 14 | saint-joseph
# Processing Record 50 of Set 14 | sungaipenuh
# Processing Record 1 of Set 15 | meiganga
# Processing Record 2 of Set 15 | nkayi
# Processing Record 3 of Set 15 | grindavik
# Processing Record 4 of Set 15 | acarau
# Processing Record 5 of Set 15 | manali
# Processing Record 6 of Set 15 | sibut
# Processing Record 7 of Set 15 | namatanai
# Processing Record 8 of Set 15 | mareeba
# Processing Record 9 of Set 15 | wattegama
# Processing Record 10 of Set 15 | zeerust
# Processing Record 11 of Set 15 | san patricio
# Processing Record 12 of Set 15 | bereda
# Processing Record 13 of Set 15 | afrikanda
# Processing Record 14 of Set 15 | oriximina
# Processing Record 15 of Set 15 | caramay
# Processing Record 16 of Set 15 | doha
# Processing Record 17 of Set 15 | ust-kuyga
# Processing Record 18 of Set 15 | dujuma
# City not found. Skipping...
# Processing Record 19 of Set 15 | le pradet
# Processing Record 20 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 21 of Set 15 | contramaestre
# Processing Record 22 of Set 15 | omsukchan
# Processing Record 23 of Set 15 | sao jose da coroa grande
# Processing Record 24 of Set 15 | verkhnyaya inta
# Processing Record 25 of Set 15 | hauterive
# Processing Record 26 of Set 15 | kopavogur
# Processing Record 27 of Set 15 | ambilobe
# Processing Record 28 of Set 15 | arrah
# Processing Record 29 of Set 15 | gunjur
# Processing Record 30 of Set 15 | ambunti
# Processing Record 31 of Set 15 | kitimat
# Processing Record 32 of Set 15 | otradnoye
# Processing Record 33 of Set 15 | copiapo
# Processing Record 34 of Set 15 | kyra
# Processing Record 35 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 15 | lakes entrance
# Processing Record 37 of Set 15 | hobyo
# Processing Record 38 of Set 15 | batagay
# Processing Record 39 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 15 | abu samrah
# Processing Record 41 of Set 15 | kidal
# Processing Record 42 of Set 15 | la asuncion
# Processing Record 43 of Set 15 | steamboat springs
# Processing Record 44 of Set 15 | estelle
# Processing Record 45 of Set 15 | vilyuysk
# Processing Record 46 of Set 15 | aflao
# Processing Record 47 of Set 15 | kysyl-syr
# Processing Record 48 of Set 15 | inirida
# Processing Record 49 of Set 15 | bac lieu
# Processing Record 50 of Set 15 | fengzhen
# Processing Record 1 of Set 16 | ciudad real
# Processing Record 2 of Set 16 | sodertalje
# City not found. Skipping...
# Processing Record 3 of Set 16 | jati
# Processing Record 4 of Set 16 | tiznit
# Processing Record 5 of Set 16 | sept-iles
# Processing Record 6 of Set 16 | saquarema
# Processing Record 7 of Set 16 | carutapera
# Processing Record 8 of Set 16 | vallenar
# Processing Record 9 of Set 16 | at-bashi
# Processing Record 10 of Set 16 | jerantut
# Processing Record 11 of Set 16 | avera
# Processing Record 12 of Set 16 | canatlan
# Processing Record 13 of Set 16 | susuman
# Processing Record 14 of Set 16 | wulanhaote
# City not found. Skipping...
# Processing Record 15 of Set 16 | iglesias
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 707

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng      Current Description  Max Temp  \
# 0      Neyshabur  36.2133   58.7958               few clouds     83.26
# 1      Jamestown  42.0970  -79.2353               few clouds     83.95
# 2         Kodiak  57.7900 -152.4072               light rain     54.91
# 3      Busselton -33.6500  115.3333          overcast clouds     52.45
# 4   Longyearbyen  78.2186   15.6401  light intensity drizzle     49.84
# 5     Talcahuano -36.7167  -73.1167                  drizzle     51.48
# 6  Sarai Alamgir  32.9012   73.7559         scattered clouds     84.85
# 7        Rikitea -23.1203 -134.9692            broken clouds     70.88
# 8         Castro -24.7911  -50.0119          overcast clouds     63.59
# 9      Ostrovnoy  68.0531   39.5131          overcast clouds     67.37
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        20          13        6.17      IR
# 1        61          20        9.22      US
# 2        88         100        5.75      US
# 3        77          97        1.28      AU
# 4        81          75        4.61      SJ
# 5       100         100       13.80      CL
# 6        76          44        4.47      PK
# 7        63          84       21.14      PF
# 8        76          95        7.00      BR
# 9        72         100       12.64      RU

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Neyshabur      IR  36.2133   58.7958     83.26        20          13
# 1      Jamestown      US  42.0970  -79.2353     83.95        61          20
# 2         Kodiak      US  57.7900 -152.4072     54.91        88         100
# 3      Busselton      AU -33.6500  115.3333     52.45        77          97
# 4   Longyearbyen      SJ  78.2186   15.6401     49.84        81          75
# 5     Talcahuano      CL -36.7167  -73.1167     51.48       100         100
# 6  Sarai Alamgir      PK  32.9012   73.7559     84.85        76          44
# 7        Rikitea      PF -23.1203 -134.9692     70.88        63          84
# 8         Castro      BR -24.7911  -50.0119     63.59        76          95
# 9      Ostrovnoy      RU  68.0531   39.5131     67.37        72         100
#
#    Wind Speed      Current Description
# 0        6.17               few clouds
# 1        9.22               few clouds
# 2        5.75               light rain
# 3        1.28          overcast clouds
# 4        4.61  light intensity drizzle
# 5       13.80                  drizzle
# 6        4.47         scattered clouds
# 7       21.14            broken clouds
# 8        7.00          overcast clouds
# 9       12.64          overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
